# %% [markdown]
# Subir primero base de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('DataBase.csv')

# %% [markdown]
# Eliminar los años 1960-2001 para reducir el espacio muestral y centrarnos en el presente siglo.

# %%
columnas_a_eliminar = [f'{year} [YR{year}]' for year in range(1960, 2001)]

df = df.drop(columns=columnas_a_eliminar)

print (df)
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 1596                                               NaN          NaN
# 1597                                               NaN          NaN
# 1598                                               NaN          NaN
# 1599  Data from database: World Development Indicators          NaN
# 1600                          Last Updated: 12/18/2023          NaN
#
#                                             Series Name        Series Code  \
# ...

# %% [markdown]
# Realizamos el primer gráfico con respecto a la población de Afghanistan que accede a electricidad en función a nivel porcentual

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_to_plot = df.iloc[0, 4:10]
plt.figure(figsize=(10, 6))

plt.bar(data_to_plot.index, data_to_plot.values, color='blue')
plt.xlabel('Columnas 5 a 10')
plt.ylabel('Valores')
plt.title('Access to electricity (% of population)of Afghanistan')
plt.show()

# %% [markdown]
# Realizamos un segundo gráfico para el caso de acceso a la electricidad rural en Afganistan a nivel porcentual

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_to_plot = df.iloc[2, 4:10]

plt.figure(figsize=(10, 6))

plt.bar(data_to_plot.index, data_to_plot.values, color='green')
plt.xlabel('Columnas 5 a 10')
plt.ylabel('Valores')
plt.title('CO2 emissions (metric tons per capita) in Afghanistan')
plt.show()
